# %%
import numpy as np
import pandas as pd
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../assets/Galtons Height Data_딸.xlsx')
df = 2.54*df
df
# Out:
#      father  daughter
# 0    199.39   175.768
# 1    199.39   175.260
# 2    199.39   175.260
# 3    191.77   166.370
# 4    191.77   166.370
# ..      ...       ...
# 428  157.48   154.940
# 429  158.75   144.780
# 430  173.99   162.560
# 431  173.99   161.290
# 432  173.99   160.020
#
# [433 rows x 2 columns]

# %%
sns.regplot(x=df.father, y=df.daughter)
plt.show()
